# %% [markdown]
# <a href="https://colab.research.google.com/github/Souzalua/estatistica/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
